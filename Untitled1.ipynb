# %%
import pandas as pd

df = pd.read_csv("netflix_sample_dataset.csv")
df.head()
# Out:
#      Title     Type     Genre Rating  Release_Year  Duration_Min Country
# 0  Movie 1  TV Show    Action      R          2005           157     USA
# 1  Movie 2    Movie  Thriller  TV-MA          2022           145  Canada
# 2  Movie 3    Movie    Comedy  PG-13          2010           114     USA
# 3  Movie 4  TV Show    Comedy  PG-13          2002           104   India
# 4  Movie 5  TV Show    Action  TV-MA          2017           128     USA

# %%
df.shape
# Out:
# (100, 7)

# %%
df.columns
# Out:
# Index(['Title', 'Type', 'Genre', 'Rating', 'Release_Year', 'Duration_Min',
#        'Country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         100 non-null    object
#  1   Type          100 non-null    object
#  2   Genre         100 non-null    object
#  3   Rating        100 non-null    object
#  4   Release_Year  100 non-null    int64
#  5   Duration_Min  100 non-null    int64
#  6   Country       100 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 5.6+ KB

# %%
df.describe()
# Out:
#        Release_Year  Duration_Min
# count    100.000000    100.000000
# mean    2011.560000    120.590000
# std        7.224146     32.130132
# min     2000.000000     60.000000
# 25%     2006.000000     98.750000
# 50%     2010.000000    118.000000
# 75%     2017.000000    146.500000
# max     2024.000000    177.000000

# %%
df.isnull().sum()
# Out:
# Title           0
# Type            0
# Genre           0
# Rating          0
# Release_Year    0
# Duration_Min    0
# Country         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Type', data=df)
plt.show()

# %%
sns.countplot(y='Genre', data=df)
plt.show()

# %%
sns.histplot(df['Release_Year'], bins=10)
plt.show()

# %%
sns.boxplot(x=df['Duration_Min'])
plt.show()

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_19533/221941791.py in <cell line: 0>()
# ----> 1 sns.heatmap(df.corr(), annot=True)
#       2 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in as_array(self, dtype, copy, na_value)
#    1692                 arr.flags.writeable = False
#    1693         else:
# -> 1694             arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695             # The underlying data was copied within _interleave, so no need
#    1696             # to further copy if copy=True or setting na_value
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in _interleave(self, dtype, na_value)
#    1751             else:
#    1752                 arr = blk.get_values(dtype)
# -> 1753             result[rl.indexer] = arr
#    1754             itemmask[rl.indexer] = 1
#    1755
#
# ValueError: could not convert string to float: 'Movie 1'

# %%
df.corr(numeric_only=True)
# Out:
#               Release_Year  Duration_Min
# Release_Year      1.000000     -0.062798
# Duration_Min     -0.062798      1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()
